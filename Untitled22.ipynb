# %% [markdown]
# <a href="https://colab.research.google.com/github/Poojaarumugavelan-cloud23/DataCamp/blob/master/Untitled22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

print("Welcome to Rock Paper Scissors Game!")
print("Choose: rock / paper / scissors\n")

choices = ["rock", "paper", "scissors"]

user_score = 0
computer_score = 0

while True:
    user = input("Your choice (or type 'exit'): ").lower()

    if user == "exit":
        break

    if user not in choices:
        print("Invalid choice! Try again.\n")
        continue

    computer = random.choice(choices)

    print("Computer chose:", computer)

    if user == computer:
        print("😐 Draw!\n")

    elif (user == "rock" and computer == "scissors") or \
         (user == "paper" and computer == "rock") or \
         (user == "scissors" and computer == "paper"):
        print("✨You Win this round!\n")
        user_score += 1

    else:
        print("💻 Computer Wins this round!\n")
        computer_score += 1

print("\n🏁 Game Over!")
print("Your Score:", user_score)
print("Computer Score:", computer_score)

if user_score > computer_score:
    print("🏆 You are the Overall Winner!")
elif user_score < computer_score:
    print("😢 Computer is the Winner!")
else:
    print("🤝 Overall Draw!")
# Out:
# Welcome to Rock Paper Scissors Game!
# Choose: rock / paper / scissors
#
# Your choice (or type 'exit'): rock
# Computer chose: rock
# 😐 Draw!
#
# Your choice (or type 'exit'): paper
# Computer chose: scissors
# 💻 Computer Wins this round!
#
# Your choice (or type 'exit'): paper
# Computer chose: rock
# ✨You Win this round!
