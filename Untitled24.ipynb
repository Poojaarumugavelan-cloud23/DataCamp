# %% [markdown]
# <a href="https://colab.research.google.com/github/Poojaarumugavelan-cloud23/DataCamp/blob/master/Untitled24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline

# Training data
documents = [
    "Congratulations you won a prize",
    "Claim your free gift now",
    "Meeting scheduled for tomorrow",
    "Project report submitted",
    "Win money instantly",
    "Team discussion at 2 PM"
]

labels = [
    "Spam",
    "Spam",
    "Not Spam",
    "Not Spam",
    "Spam",
    "Not Spam"
]

# Create model
model = Pipeline([
    ('tfidf', TfidfVectorizer()),
    ('classifier', MultinomialNB())
])

# Train model
model.fit(documents, labels)

# Test
new_doc = ["Free money offer available now"]
prediction = model.predict(new_doc)

print("Prediction:", prediction[0])
# Out:
# Prediction: Spam

# %%
pip install scikit-learn
